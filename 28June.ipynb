# %% [markdown]
# # **Introduction to Matplotlib**
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It is one of the most widely used data visualization libraries in the Python ecosystem and is highly regarded for its flexibility and ease of use. Matplotlib was originally developed by John D. Hunter in 2003 and has since become an essential tool for data scientists, analysts, and researchers.

# %% [markdown]
# ## Key Features:
# ### **1.Versatility:**
# Matplotlib can generate a wide variety of plots and charts, including line plots, scatter plots, bar plots, histograms, pie charts, and 3D plots.
#
# ### **2.Customization:**
# Almost every element of a plot can be customized, including line styles, colors, fonts, and more. This allows for the creation of highly tailored and publication-quality visualizations.
#
# ### **3.Integration:**
# Matplotlib integrates seamlessly with other popular Python libraries such as NumPy, pandas, and SciPy, making it a powerful tool for data analysis and scientific computing.
# ### **4.Interactivity:**
# With the help of additional libraries like matplotlib.widgets and mpld3, users can create interactive plots that can be embedded in web applications and Jupyter notebooks.

# %% [markdown]
# ## Why Use Matplotlib?
# ### **1.Ease of Use:**
# Matplotlib's simple and intuitive API allows users to create basic plots with minimal code. It also offers advanced functionalities for more complex visualizations.
# ### **High-Quality Output:**
# Produces high-quality, publication-ready visualizations in various formats such as PNG, PDF, SVG, and EPS.
# ### **Community and Support:**
# A large and active user community provides ample tutorials, documentation, and support online.

# %% [markdown]
# ## Installation
# To install Matplotlib, you can use pip:

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: C:\Users\bhati\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Basic Plotting with Matplotlib
# ### Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.random.rand(50)
y = np.random.rand(50)

# Plot
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 2]

# Plot
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.show()

# %% [markdown]
# ### Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data = np.random.randn(1000)

# Plot
plt.hist(data, bins=30, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
import matplotlib.pyplot as plt

# Data
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]

# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# ### HeatMap

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data = np.random.rand(10, 10)

# Plot
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %% [markdown]
# ## Plotting Questions and Answers
# ### Question 1
#
# Plot a histogram of 1000 random numbers generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
data = np.random.randn(1000)

# Plot
plt.hist(data, bins=30, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 1000 Random Numbers')
plt.show()

# %% [markdown]
# ### Question 2
#
# Create a pie chart showing the distribution of 4 categories with the following values: [15, 30, 45, 10].

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [15, 30, 45, 10]

# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Pie Chart of Categories')
plt.show()

# %% [markdown]
# ### Question 3
#
# Generate a plot showing the sine and cosine functions on the same graph.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Plot
plt.plot(x, y1, label='Sine')
plt.plot(x, y2, label='Cosine')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine and Cosine Functions')
plt.legend()
plt.show()
